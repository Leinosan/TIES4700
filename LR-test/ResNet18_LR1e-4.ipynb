# %%
import random
from dataclasses import dataclass
from typing import List, Tuple

import numpy as np
from sklearn.metrics import roc_auc_score, average_precision_score

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Subset
from torchvision import datasets, transforms
from torchvision.models import resnet18, ResNet18_Weights
from PIL import Image, ImageOps


@dataclass
class CFG:
    train_root: str = r"C:\Users\Mikko\RODI-DATA\Train" # train data root
    img_size: int = 224
    batch_size: int = 64
    epochs: int = 6
    lr: float = 1e-4
    seed: int = 42
    num_workers: int = 0
    val_frac: float = 0.2
    neg_samples: int = 4000
    threshold: float = 0.5

cfg = CFG()

device = "cuda" if torch.cuda.is_available() else "cpu"
print("DEVICE:", device)

random.seed(cfg.seed)
torch.manual_seed(cfg.seed)
if device == "cuda":
    torch.cuda.manual_seed_all(cfg.seed)
    torch.backends.cudnn.benchmark = True

scaler = torch.amp.GradScaler("cuda", enabled=(device == "cuda"))



# Preprocessing
class SquarePad:
    def __call__(self, img: Image.Image) -> Image.Image:
        w, h = img.size
        m = max(w, h)
        hp = (m - w) // 2
        vp = (m - h) // 2
        padding = (hp, vp, m - w - hp, m - h - vp)
        return ImageOps.expand(img, padding, fill=0)

def stratified_split_on_subset(indices: List[int], targets: List[int], fish_idx: int, val_frac: float):
    fish = [i for i in indices if targets[i] == fish_idx]
    neg  = [i for i in indices if targets[i] != fish_idx]
    random.shuffle(fish)
    random.shuffle(neg)

    n_fish_val = max(1, int(len(fish) * val_frac))
    n_neg_val  = max(1, int(len(neg)  * val_frac))

    val_idx = fish[:n_fish_val] + neg[:n_neg_val]
    train_idx = fish[n_fish_val:] + neg[n_neg_val:]

    random.shuffle(train_idx)
    random.shuffle(val_idx)
    return train_idx, val_idx

train_tf = transforms.Compose([
    SquarePad(),
    transforms.Resize((cfg.img_size, cfg.img_size)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomRotation(15),
    transforms.ColorJitter(brightness=0.2, contrast=0.2),
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406),
                         (0.229, 0.224, 0.225)),
])

val_tf = transforms.Compose([
    SquarePad(),
    transforms.Resize((cfg.img_size, cfg.img_size)),
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406),
                         (0.229, 0.224, 0.225)),
])

full_train = datasets.ImageFolder(cfg.train_root, transform=train_tf)
full_val   = datasets.ImageFolder(cfg.train_root, transform=val_tf)

print("Classes:", full_train.class_to_idx)
fish_idx = full_train.class_to_idx["fish"]
targets = full_train.targets



# Subset: all fish + N negatives
fish_indices = [i for i, y in enumerate(targets) if y == fish_idx]
neg_indices  = [i for i, y in enumerate(targets) if y != fish_idx]

random.shuffle(neg_indices)
neg_indices = neg_indices[:cfg.neg_samples]

subset_indices = fish_indices + neg_indices
random.shuffle(subset_indices)

print(f"Subset size: {len(subset_indices)} | fish={len(fish_indices)} | neg_used={len(neg_indices)}")



# Split
train_idx, val_idx = stratified_split_on_subset(subset_indices, targets, fish_idx, cfg.val_frac)

train_ds = Subset(full_train, train_idx)
val_ds   = Subset(full_val, val_idx)

train_fish = sum(1 for i in train_idx if targets[i] == fish_idx)
train_neg  = len(train_idx) - train_fish
val_fish   = sum(1 for i in val_idx if targets[i] == fish_idx)
val_neg    = len(val_idx) - val_fish

print(f"Train: {len(train_idx)} (fish {train_fish}, neg {train_neg})")
print(f"Val  : {len(val_idx)} (fish {val_fish}, neg {val_neg})")

train_loader = DataLoader(train_ds, batch_size=cfg.batch_size, shuffle=True,
                          num_workers=cfg.num_workers, pin_memory=(device=="cuda"))
val_loader   = DataLoader(val_ds, batch_size=cfg.batch_size, shuffle=False,
                          num_workers=cfg.num_workers, pin_memory=(device=="cuda"))



# Model
model = resnet18(weights=ResNet18_Weights.DEFAULT)
in_features = model.fc.in_features
model.fc = nn.Linear(in_features, 2)
model = model.to(device)

fish_weight = train_neg / max(1, train_fish)
class_weights = torch.tensor([1.0, float(fish_weight)], device=device)
criterion = nn.CrossEntropyLoss(weight=class_weights)
optimizer = optim.Adam(model.parameters(), lr=cfg.lr)



# Metrics
def print_metrics(tag: str, m: dict):
    print(
        f"{tag} | "
        f"Acc={m['Acc']*100:.1f}% "
        f"P_fish={m['P_fish']*100:.1f}% R_fish={m['R_fish']*100:.1f}% F1_fish={m['F1_fish']*100:.1f}% | "
        f"P_non={m['P_non']*100:.1f}% R_non={m['R_non']*100:.1f}% | "
        f"AUROC={m['AUROC']:.3f} AUPRC={m['AUPRC']:.3f} | "
        f"TP={m['TP']} FP={m['FP']} FN={m['FN']} TN={m['TN']}"
    )

@torch.no_grad()
def compute_metrics_resnet(model, loader, fish_idx, device, threshold=0.5):
    model.eval()
    tp = fp = fn = tn = 0
    y_true_all, y_score_all = [], []

    for x, y_multi in loader:
        x = x.to(device, non_blocking=True)
        y_true = (y_multi == fish_idx).to(device)  # bool

        logits = model(x)  # (B,2)
        probs = torch.softmax(logits, dim=1)[:, 1]  # P(fish)

        y_pred = (probs >= threshold)

        tp += (y_pred & y_true).sum().item()
        fp += (y_pred & ~y_true).sum().item()
        fn += (~y_pred & y_true).sum().item()
        tn += (~y_pred & ~y_true).sum().item()

        y_true_all.append(y_true.int().cpu().numpy())
        y_score_all.append(probs.detach().cpu().numpy())

    y_true_all = np.concatenate(y_true_all)
    y_score_all = np.concatenate(y_score_all)

    p_fish = tp / (tp + fp + 1e-9)
    r_fish = tp / (tp + fn + 1e-9)
    f1_fish = 2 * p_fish * r_fish / (p_fish + r_fish + 1e-9)

    p_non = tn / (tn + fn + 1e-9)
    r_non = tn / (tn + fp + 1e-9)

    acc = (tp + tn) / (tp + tn + fp + fn + 1e-9)

    auroc = roc_auc_score(y_true_all, y_score_all)
    auprc = average_precision_score(y_true_all, y_score_all)

    return {
        "P_fish": p_fish, "R_fish": r_fish, "F1_fish": f1_fish,
        "P_non": p_non, "R_non": r_non,
        "Acc": acc, "AUROC": auroc, "AUPRC": auprc,
        "TP": tp, "FP": fp, "FN": fn, "TN": tn
    }



# Train
print("\nStarting training...")
for epoch in range(1, cfg.epochs + 1):
    model.train()
    running = 0.0

    for x, y_multi in train_loader:
        x = x.to(device, non_blocking=True)
        y = (y_multi == fish_idx).long().to(device, non_blocking=True)

        optimizer.zero_grad(set_to_none=True)
        with torch.autocast(device_type="cuda", enabled=(device == "cuda")):
            logits = model(x)
            loss = criterion(logits, y)

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        running += loss.item() * x.size(0)

    val_m = compute_metrics_resnet(model, val_loader, fish_idx, device, threshold=cfg.threshold)

    print(f"Epoch {epoch:02d} | train_loss={running/len(train_ds):.4f}")
    print_metrics("  VAL  ", val_m)

# Final train + val
final_train = compute_metrics_resnet(model, train_loader, fish_idx, device, threshold=cfg.threshold)
final_val   = compute_metrics_resnet(model, val_loader, fish_idx, device, threshold=cfg.threshold)

print("\nFinal metrics:")
print_metrics("  FINAL TRAIN", final_train)
print_metrics("  FINAL VAL  ", final_val)
print("Done.")
# Out:
# DEVICE: cuda
# Classes: {'artifact': 0, 'fish': 1, 'insect': 2, 'leave': 3, 'partial-overlapping-objects': 4, 'rounded': 5, 'shadow': 6, 'variable': 7, 'wormish': 8}
# Subset size: 4357 | fish=357 | neg_used=4000
# Train: 3486 (fish 286, neg 3200)
# Val  : 871 (fish 71, neg 800)
#
# Starting training...
# Epoch 01 | train_loss=0.1606
#   VAL   | Acc=98.7% P_fish=94.1% R_fish=90.1% F1_fish=92.1% | P_non=99.1% R_non=99.5% | AUROC=0.991 AUPRC=0.965 | TP=64 FP=4 FN=7 TN=796
# Epoch 02 | train_loss=0.0554
#   VAL   | Acc=98.2% P_fish=83.1% R_fish=97.2% F1_fish=89.6% | P_non=99.7% R_non=98.2% | AUROC=0.996 AUPRC=0.975 | TP=69 FP=14 FN=2 TN=786
# Epoch 03 | train_loss=0.0601
#   VAL   | Acc=99.2% P_fish=95.7% R_fish=94.4% F1_fish=95.0% | P_non=99.5% R_non=99.6% | AUROC=1.000 AUPRC=0.995 | TP=67 FP=3 FN=4 TN=797
# Epoch 04 | train_loss=0.0215
#   VAL   | Acc=99.2% P_fish=93.2% R_fish=97.2% F1_fish=95.2% | P_non=99.7% R_non=99.4% | AUROC=0.998 AUPRC=0.987 | TP=69 FP=5 FN=2 TN=795
# Epoch 05 | train_loss=0.0225
#   VAL   | Acc=99.2% P_fish=95.7% R_fish=94.4% F1_fish=95.0% | P_non=99.5% R_non=99.6% | AUROC=0.999 AUPRC=0.990 | TP=67 FP=3 FN=4 TN=797
# Epoch 06 | train_loss=0.0212
#   VAL   | Acc=99.0% P_fish=95.6% R_fish=91.5% F1_fish=93.5% | P_non=99.3% R_non=99.6% | AUROC=0.996 AUPRC=0.978 | TP=65 FP=3 FN=6 TN=797
#
# Final metrics:
#   FINAL TRAIN | Acc=99.5% P_fish=98.6% R_fish=95.5% F1_fish=97.0% | P_non=99.6% R_non=99.9% | AUROC=1.000 AUPRC=0.997 | TP=273 FP=4 FN=13 TN=3196
#   FINAL VAL   | Acc=99.0% P_fish=95.6% R_fish=91.5% F1_fish=93.5% | P_non=99.3% R_non=99.6% | AUROC=0.996 AUPRC=0.978 | TP=65 FP=3 FN=6 TN=797
# Done.
